# %% [markdown]
# # 🧠 Python Review: Variables to Tuples
#
# ---
#
# ## ✅ 1. Variables
#
# ### 📝 Exercises & Solutions
# 1. Assign your name to a variable and print it:
# ```python
# name = "Sys Minn Kha"
# print(name)
# ```
#
# 2. Swap the values of two variables:
# ```python
# a = 5
# b = 10
# a, b = b, a
# print(a, b)
# ```
#
# 3. Convert an integer to float and vice versa:
# ```python
# num = 7
# float_num = float(num)
# int_num = int(float_num)
# print(float_num, int_num)
# ```
#
# ---
#
# ## ✅ 2. Strings
#
# ### 📝 Exercises & Solutions
# 1. Extract "World":
# ```python
# s = "Hello World"
# print(s[6:])
# ```
#
# 2. Count "a" in "banana":
# ```python
# word = "banana"
# print(word.count("a"))
# ```
#
# 3. Uppercase and split:
# ```python
# text = "Python is fun"
# print(text.upper().split())
# ```
#
# ---
#
# ## ✅ 3. Print Formatting
#
# ### 📝 Exercises & Solutions
# 1. Format sentence:
# ```python
# name = "Sys"
# age = 24
# color = "blue"
# print(f"My name is {name}, I am {age} years old, and my favorite color is {color}.")
# ```
#
# 2. Two decimal places:
# ```python
# pi = 3.1415926
# print(f"{pi:.2f}")
# ```
#
# ---
#
# ## ✅ 4. Lists
#
# ### 📝 Exercises & Solutions
# 1. Reverse list:
# ```python
# nums = [1, 2, 3, 4, 5]
# nums.reverse()
# print(nums)
# ```
#
# 2. Sort strings:
# ```python
# names = ["Charlie", "Alice", "Bob"]
# names.sort()
# print(names)
# ```
#
# 3. Remove second item:
# ```python
# items = ["a", "b", "c"]
# items.pop(1)
# print(items)
# ```
#
# ---
#
# ## ✅ 5. Dictionaries
#
# ### 📝 Exercises & Solutions
# 1. Student dictionary:
# ```python
# student = {"name": "Sys", "age": 24, "major": "CS"}
# print(student)
# ```
#
# 2. Update age:
# ```python
# student["age"] = 25
# print(student)
# ```
#
# 3. Add GPA:
# ```python
# student["GPA"] = 3.8
# print(student)
# ```
#
# ---
#
# ## ✅ 6. Tuples
#
# ### 📝 Exercises & Solutions
# 1. Create tuple:
# ```python
# t = (1, 2, 3)
# print(t)
# ```
#
# 2. Try to modify:
# ```python
# # t[0] = 100  # This will raise an error
# ```
#
# 3. Tuple as dict key:
# ```python
# location = {(35.0, -120.0): "California"}
# print(location[(35.0, -120.0)])
# ```
